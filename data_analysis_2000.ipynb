# %% [markdown]
# ## 收集人口数据
#
# 从[国家统计局](https://data.stats.gov.cn/)网站上可以收集到官方版本的各种国内数据和近几次人口普查的详细数据。

# %% [markdown]
# ## 分析历史数据
#
# 对历史数据进行可视化+从各个不同的角度进行部分分析。 结合具体时间进行详细分析。

# %%
import pandas as pd
from pyecharts import options as opts
from pyecharts.charts import Geo, Timeline, Grid, Bar, Map, Pie, Line
from pyecharts.globals import ChartType, ThemeType
from typing import List
from pyecharts.commons.utils import JsCode
from pyecharts.charts import Timeline, Grid, Bar, Map, Pie, Line

# %% [markdown]
# ### 1. 可视化第五次人口普查数据
#
# #### （1）全国各地区总人口数量与城乡人口数量

# %%
root_path = '第五次人口普查/'

full_view_path = root_path + 't0101.xls'
data = pd.read_excel(io=full_view_path,header=6).dropna()
data.columns = [i for i in range(17)]
data
# Out:
#           0           1           2          3           4           5   \
# 1        北京市   4417045.0   4096844.0   320201.0  13569194.0   7074518.0
# 2        天津市   3079377.0   2976741.0   102636.0   9848731.0   5016375.0
# 3        河北省  18302744.0  17934977.0   367767.0  66684419.0  33936333.0
# 4        山西省   8825948.0   8650261.0   175687.0  32471242.0  16800758.0
# 5     内蒙古自治区   6907890.0   6784470.0   123420.0  23323347.0  12061615.0
# 7        辽宁省  13046524.0  12866262.0   180262.0  41824412.0  21323383.0
# 8        吉林省   7953615.0   7848446.0   105169.0  26802191.0  13720747.0
# 9       黑龙江省  11070922.0  10955750.0   115172.0  36237576.0  18520747.0
# 11       上海市   5642588.0   5299068.0   343520.0  16407734.0   8430262.0
# 12       江苏省  22034267.0  21375726.0   658541.0  73043577.0  36982038.0
# 13       浙江省  14789669.0  14136916.0   652753.0  45930651.0  23581512.0
# 14       安徽省  16505420.0  16313885.0   191535.0  58999948.0  30437820.0
# 15       福建省   9325897.0   8743252.0   582645.0  34097947.0  17568535.0
# 16       江西省  10444706.0  10168639.0   276067.0  40397598.0  20990240.0
# 17       山东省  27320402.0  26709328.0   611074.0  89971789.0  45542060.0
# 19       河南省  24590997.0  24247377.0   343620.0  91236854.0  47046599.0
# 20       湖北省  16168718.0  15613793.0   554925.0  59508870.0  30982241.0
# 21       湖南省  18003773.0  17662105.0   341668.0  63274173.0  32993704.0
# 22       广东省  21538730.0  18762127.0  2776603.0  85225007.0  43381720.0
# 23   广西壮族自治区  11517720.0  11309236.0   208484.0  43854538.0  23239376.0
# 24       海南省   1807521.0   1750710.0    56811.0   7559035.0   4002445.0
# 26       重庆市   9318199.0   9141558.0   176641.0  30512763.0  15841429.0
# 27       四川省  24092307.0  23638429.0   453878.0  82348296.0  42561620.0
# 28       贵州省   9338955.0   9239409.0    99546.0  35247695.0  18464477.0
# 29       云南省  11120685.0  10853172.0   267513.0  42360089.0  22194343.0
# 30     西藏自治区    544909.0    531571.0    13338.0   2616329.0   1325371.0
# 32       陕西省   9730003.0   9429484.0   300519.0  35365072.0  18378759.0
# 33       甘肃省   6251195.0   6086988.0   164207.0  25124282.0  13021654.0
# 34       青海省   1202626.0   1173977.0    28649.0   4822963.0   2489590.0
# 35   宁夏回族自治区   1423699.0   1396870.0    26829.0   5486393.0   2813517.0
# 36  新疆维吾尔自治区   4916647.0   4793826.0   122821.0  18459511.0   9552181.0
#
#             6       7           8           9           10      11  \
# 1    6494676.0  108.93  11922945.0   5925670.0   5997275.0   98.81
# 2    4832356.0  103.81   9218220.0   4605720.0   4612500.0   99.85
# 3   32748086.0  103.63  64296922.0  32494651.0  31802271.0  102.18
# 4   15670484.0  107.21  31448836.0  16107462.0  15341374.0  104.99
# 5   11261732.0  107.10  22618741.0  11611976.0  11006765.0  105.50
# 7   20501029.0  104.01  40597750.0  20547768.0  20049982.0  102.48
# 8   13081444.0  104.89  26076948.0  13265133.0  12811815.0  103.54
# 9   17716829.0  104.54  35457466.0  18040981.0  17416485.0  103.59
# 11   7977472.0  105.68  14787225.0   7381235.0   7405990.0   99.67
# 12  36061539.0  102.55  69372929.0  34775918.0  34597011.0  100.52
# 13  22349139.0  105.51  42437464.0  21497896.0  20939568.0  102.67
# 14  28562128.0  106.57  57683856.0  29578590.0  28105266.0  105.24
# 15  16529412.0  106.29  31251540.0  15870742.0  15380798.0  103.19
# 16  19407358.0  108.16  38635039.0  19900153.0  18734886.0  106.22
# 17  44429729.0  102.50  85995937.0  43264425.0  42731512.0  101.25
# 19  44190255.0  106.46  89285110.0  45794133.0  43490977.0  105.30
# 20  28526629.0  108.61  55178797.0  28439557.0  26739240.0  106.36
# 21  30280469.0  108.96  61061446.0  31648823.0  29412623.0  107.60
# 22  41843287.0  103.68  69739958.0  35467809.0  34272149.0  103.49
# 23  20615162.0  112.73  42480672.0  22385025.0  20095647.0  111.39
# 24   3556590.0  112.54   7191829.0   3773762.0   3418067.0  110.41
# 26  14671334.0  107.98  29483651.0  15169064.0  14314587.0  105.97
# 27  39786676.0  106.97  78760676.0  40370050.0  38390626.0  105.16
# 28  16783218.0  110.02  34591772.0  18002003.0  16589769.0  108.51
# 29  20165746.0  110.06  40474089.0  20911957.0  19562132.0  106.90
# 30   1290958.0  102.67   2526981.0   1257371.0   1269610.0   99.04
# 32  16986313.0  108.20  33687093.0  17302351.0  16384742.0  105.60
# 33  12102628.0  107.59  24261648.0  12406398.0  11855250.0  104.65
# 34   2333373.0  106.69   4643526.0   2355416.0   2288110.0  102.94
# 35   2672876.0  105.26   5338041.0   2710328.0   2627713.0  103.14
# 36   8907330.0  107.24  17764112.0   9067273.0   8696839.0  104.26
#
#             12         13         14      15    16
# 1    1646249.0  1148848.0   497401.0  230.97  2.91
# 2     630511.0   410655.0   219856.0  186.78  3.10
# 3    2387497.0  1441682.0   945815.0  152.43  3.59
# 4    1022406.0   693296.0   329110.0  210.66  3.64
# 5     704606.0   449639.0   254967.0  176.35  3.33
# 7    1226662.0   775615.0   451047.0  171.96  3.16
# 8     725243.0   455614.0   269629.0  168.98  3.32
# 9     780110.0   479766.0   300344.0  159.74  3.24
# 11   1620509.0  1049027.0   571482.0  183.56  2.79
# 12   3670648.0  2206120.0  1464528.0  150.64  3.25
# 13   3493187.0  2083616.0  1409571.0  147.82  3.00
# 14   1316092.0   859230.0   456862.0  188.07  3.54
# 15   2846407.0  1697793.0  1148614.0  147.81  3.57
# 16   1762559.0  1090087.0   672472.0  162.10  3.80
# 17   3975852.0  2277635.0  1698217.0  134.12  3.22
# 19   1951744.0  1252466.0   699278.0  179.11  3.68
# 20   4330073.0  2542684.0  1787389.0  142.26  3.53
# 21   2212727.0  1344881.0   867846.0  154.97  3.46
# 22  15485049.0  7913911.0  7571138.0  104.53  3.72
# 23   1373866.0   854351.0   519515.0  164.45  3.76
# 24    367206.0   228683.0   138523.0  165.09  4.11
# 26   1029112.0   672365.0   356747.0  188.47  3.23
# 27   3587620.0  2191570.0  1396050.0  156.98  3.33
# 28    655923.0   462474.0   193449.0  239.07  3.74
# 29   1886000.0  1282386.0   603614.0  212.45  3.73
# 30     89348.0    68000.0    21348.0  318.53  4.75
# 32   1677979.0  1076408.0   601571.0  178.93  3.57
# 33    862634.0   615256.0   247378.0  248.71  3.99
# 34    179437.0   134174.0    45263.0  296.43  3.96
# 35    148352.0   103189.0    45163.0  228.48  3.82
# 36    695399.0   484908.0   210491.0  230.37  3.71

# %%
change_dict = {'广西壮族自治区':'广西','西藏自治区':'西藏','新疆维吾尔自治区':'新疆',"内蒙古自治区":"内蒙古","宁夏回族自治区":"宁夏"}
area_list_full = data[0].values.tolist()
area_list = [area[:-1] if area not in change_dict.keys() else change_dict[area] for area in area_list_full]
total_pop_list = data[4].values.tolist()
man_list = data[5].values.tolist()
woman_list = data[6].values.tolist()
average_per_house_list = data[16].values.tolist()

# %%
c = (
    Map()
    .add(
        "population",
        [list(z) for z in zip(area_list, total_pop_list)],
        "china"
    )
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_ = 100000000,is_piecewise=True),
        title_opts=opts.TitleOpts(title="Population_Map_For_2000"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="1d39a5c8e0c14026abe742a74b6bdb84" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_1d39a5c8e0c14026abe742a74b6bdb84 = echarts.init(
#                     document.getElementById('1d39a5c8e0c14026abe742a74b6bdb84'), 'white', {renderer: 'canvas'});
#                 var option_1d39a5c8e0c14026abe742a74b6bdb84 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "population",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 13569194.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 9848731.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 66684419.0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 32471242.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 23323347.0
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 41824412.0
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 26802191.0
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 36237576.0
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 16407734.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 73043577.0
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 45930651.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 58999948.0
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 34097947.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 40397598.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 89971789.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 91236854.0
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 59508870.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 63274173.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 85225007.0
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 43854538.0
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 7559035.0
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 30512763.0
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 82348296.0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 35247695.0
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 42360089.0
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 2616329.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 35365072.0
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 25124282.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 4822963.0
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 5486393.0
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 18459511.0
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "population"
#             ],
#             "selected": {
#                 "population": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Population_Map_For_2000",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100000000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_1d39a5c8e0c14026abe742a74b6bdb84.setOption(option_1d39a5c8e0c14026abe742a74b6bdb84);
#         });
#     </script>

# %%
def change_area(area_list, value_list):
    Xy = [(xi, yi) for xi, yi in zip(area_list, value_list)]
    sorted_Xy = sorted(Xy,key = lambda x: x[1],reverse= 1)
    sorted_area = [xi for xi,_ in sorted_Xy]
    sorted_value = [yi for _,yi in sorted_Xy]
    return sorted_area, sorted_value
    
sorted_area,sorted_total_pop = change_area(area_list,total_pop_list)

# %%
bar = (
        Bar(init_opts=opts.InitOpts(bg_color='rgba(51,51,51)'))
        .add_xaxis(xaxis_data=sorted_area)
        .add_yaxis(
            series_name="",
            y_axis=sorted_total_pop,
            label_opts=opts.LabelOpts(
                is_show=True, position="right", formatter="{b} : {c}"
            ),
        )
        .reversal_axis()
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(
                max_=100000000, axislabel_opts=opts.LabelOpts(is_show=False)
            ),
            yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(is_show=False)),
            tooltip_opts=opts.TooltipOpts(is_show=False),
            visualmap_opts=opts.VisualMapOpts(
                is_calculable=True,
                dimension=0,
                pos_left="10",
                pos_top="top",
                range_text=["High", "Low"],
                range_color=["lightskyblue", "yellow", "orangered"],
                textstyle_opts=opts.TextStyleOpts(color="#ddd"),
                min_=0,
                max_=100000000,
            ),
        )
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1697f91c9ac74c3e9565739f0e7b1702" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1697f91c9ac74c3e9565739f0e7b1702 = echarts.init(
#                     document.getElementById('1697f91c9ac74c3e9565739f0e7b1702'), 'white', {renderer: 'canvas'});
#                 var option_1697f91c9ac74c3e9565739f0e7b1702 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 91236854.0,
#                 89971789.0,
#                 85225007.0,
#                 82348296.0,
#                 73043577.0,
#                 66684419.0,
#                 63274173.0,
#                 59508870.0,
#                 58999948.0,
#                 45930651.0,
#                 43854538.0,
#                 42360089.0,
#                 41824412.0,
#                 40397598.0,
#                 36237576.0,
#                 35365072.0,
#                 35247695.0,
#                 34097947.0,
#                 32471242.0,
#                 30512763.0,
#                 26802191.0,
#                 25124282.0,
#                 23323347.0,
#                 18459511.0,
#                 16407734.0,
#                 13569194.0,
#                 9848731.0,
#                 7559035.0,
#                 5486393.0,
#                 4822963.0,
#                 2616329.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "max": 100000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u5357",
#                 "\u5c71\u4e1c",
#                 "\u5e7f\u4e1c",
#                 "\u56db\u5ddd",
#                 "\u6c5f\u82cf",
#                 "\u6cb3\u5317",
#                 "\u6e56\u5357",
#                 "\u6e56\u5317",
#                 "\u5b89\u5fbd",
#                 "\u6d59\u6c5f",
#                 "\u5e7f\u897f",
#                 "\u4e91\u5357",
#                 "\u8fbd\u5b81",
#                 "\u6c5f\u897f",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u9655\u897f",
#                 "\u8d35\u5dde",
#                 "\u798f\u5efa",
#                 "\u5c71\u897f",
#                 "\u91cd\u5e86",
#                 "\u5409\u6797",
#                 "\u7518\u8083",
#                 "\u5185\u8499\u53e4",
#                 "\u65b0\u7586",
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u5929\u6d25",
#                 "\u6d77\u5357",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_1697f91c9ac74c3e9565739f0e7b1702.setOption(option_1697f91c9ac74c3e9565739f0e7b1702);
#         });
#     </script>

# %% [markdown]
# #### 男性人数

# %%
c = (
    Map()
    .add(
        "population",
        [list(z) for z in zip(area_list, man_list)],
        "china"
    )
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_ = 50000000,is_piecewise=True),
        title_opts=opts.TitleOpts(title="Male_Population_Map_For_2000"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="c1548ec05bf241b89b98382d4fef9188" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_c1548ec05bf241b89b98382d4fef9188 = echarts.init(
#                     document.getElementById('c1548ec05bf241b89b98382d4fef9188'), 'white', {renderer: 'canvas'});
#                 var option_c1548ec05bf241b89b98382d4fef9188 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "population",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 7074518.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 5016375.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 33936333.0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 16800758.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 12061615.0
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 21323383.0
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 13720747.0
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 18520747.0
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 8430262.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 36982038.0
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 23581512.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 30437820.0
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 17568535.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 20990240.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 45542060.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 47046599.0
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 30982241.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 32993704.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 43381720.0
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 23239376.0
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 4002445.0
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 15841429.0
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 42561620.0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 18464477.0
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 22194343.0
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1325371.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 18378759.0
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 13021654.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 2489590.0
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 2813517.0
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 9552181.0
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "population"
#             ],
#             "selected": {
#                 "population": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Male_Population_Map_For_2000",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 50000000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_c1548ec05bf241b89b98382d4fef9188.setOption(option_c1548ec05bf241b89b98382d4fef9188);
#         });
#     </script>

# %%
sorted_area,sorted_man = change_area(area_list,man_list)
bar = (
        Bar(init_opts=opts.InitOpts(bg_color='rgba(51,51,51)'))
        .add_xaxis(xaxis_data=sorted_area)
        .add_yaxis(
            series_name="",
            y_axis=sorted_man,
            label_opts=opts.LabelOpts(
                is_show=True, position="right", formatter="{b} : {c}"
            ),
        )
        .reversal_axis()
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(
                max_=50000000, axislabel_opts=opts.LabelOpts(is_show=False)
            ),
            yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(is_show=False)),
            tooltip_opts=opts.TooltipOpts(is_show=False),
            visualmap_opts=opts.VisualMapOpts(
                is_calculable=True,
                dimension=0,
                pos_left="10",
                pos_top="top",
                range_text=["High", "Low"],
                range_color=["lightskyblue", "yellow", "orangered"],
                textstyle_opts=opts.TextStyleOpts(color="#ddd"),
                min_=0,
                max_=50000000,
            ),
        )
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="adf6a49215a5462a9d4020a2183072b0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_adf6a49215a5462a9d4020a2183072b0 = echarts.init(
#                     document.getElementById('adf6a49215a5462a9d4020a2183072b0'), 'white', {renderer: 'canvas'});
#                 var option_adf6a49215a5462a9d4020a2183072b0 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 47046599.0,
#                 45542060.0,
#                 43381720.0,
#                 42561620.0,
#                 36982038.0,
#                 33936333.0,
#                 32993704.0,
#                 30982241.0,
#                 30437820.0,
#                 23581512.0,
#                 23239376.0,
#                 22194343.0,
#                 21323383.0,
#                 20990240.0,
#                 18520747.0,
#                 18464477.0,
#                 18378759.0,
#                 17568535.0,
#                 16800758.0,
#                 15841429.0,
#                 13720747.0,
#                 13021654.0,
#                 12061615.0,
#                 9552181.0,
#                 8430262.0,
#                 7074518.0,
#                 5016375.0,
#                 4002445.0,
#                 2813517.0,
#                 2489590.0,
#                 1325371.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "max": 50000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u5357",
#                 "\u5c71\u4e1c",
#                 "\u5e7f\u4e1c",
#                 "\u56db\u5ddd",
#                 "\u6c5f\u82cf",
#                 "\u6cb3\u5317",
#                 "\u6e56\u5357",
#                 "\u6e56\u5317",
#                 "\u5b89\u5fbd",
#                 "\u6d59\u6c5f",
#                 "\u5e7f\u897f",
#                 "\u4e91\u5357",
#                 "\u8fbd\u5b81",
#                 "\u6c5f\u897f",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u8d35\u5dde",
#                 "\u9655\u897f",
#                 "\u798f\u5efa",
#                 "\u5c71\u897f",
#                 "\u91cd\u5e86",
#                 "\u5409\u6797",
#                 "\u7518\u8083",
#                 "\u5185\u8499\u53e4",
#                 "\u65b0\u7586",
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u5929\u6d25",
#                 "\u6d77\u5357",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 50000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_adf6a49215a5462a9d4020a2183072b0.setOption(option_adf6a49215a5462a9d4020a2183072b0);
#         });
#     </script>

# %% [markdown]
# #### 女性人数

# %%
c = (
    Map()
    .add(
        "population",
        [list(z) for z in zip(area_list, woman_list)],
        "china"
    )
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_ = 50000000,is_piecewise=True),
        title_opts=opts.TitleOpts(title="Female_Population_Map_For_2000"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="b51487520bb84165a3aabd1656742a5d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_b51487520bb84165a3aabd1656742a5d = echarts.init(
#                     document.getElementById('b51487520bb84165a3aabd1656742a5d'), 'white', {renderer: 'canvas'});
#                 var option_b51487520bb84165a3aabd1656742a5d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "population",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 6494676.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 4832356.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 32748086.0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 15670484.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 11261732.0
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 20501029.0
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 13081444.0
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 17716829.0
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 7977472.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 36061539.0
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 22349139.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 28562128.0
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 16529412.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 19407358.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 44429729.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 44190255.0
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 28526629.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 30280469.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 41843287.0
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 20615162.0
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 3556590.0
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 14671334.0
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 39786676.0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 16783218.0
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 20165746.0
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1290958.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 16986313.0
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 12102628.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 2333373.0
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 2672876.0
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 8907330.0
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "population"
#             ],
#             "selected": {
#                 "population": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Female_Population_Map_For_2000",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 50000000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_b51487520bb84165a3aabd1656742a5d.setOption(option_b51487520bb84165a3aabd1656742a5d);
#         });
#     </script>

# %%
sorted_area,sorted_woman = change_area(area_list,woman_list)
bar = (
        Bar(init_opts=opts.InitOpts(bg_color='rgba(51,51,51)'))
        .add_xaxis(xaxis_data=sorted_area)
        .add_yaxis(
            series_name="",
            y_axis=sorted_woman,
            label_opts=opts.LabelOpts(
                is_show=True, position="right", formatter="{b} : {c}"
            ),
        )
        .reversal_axis()
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(
                max_=50000000, axislabel_opts=opts.LabelOpts(is_show=False)
            ),
            yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(is_show=False)),
            tooltip_opts=opts.TooltipOpts(is_show=False),
            visualmap_opts=opts.VisualMapOpts(
                is_calculable=True,
                dimension=0,
                pos_left="10",
                pos_top="top",
                range_text=["High", "Low"],
                range_color=["lightskyblue", "yellow", "orangered"],
                textstyle_opts=opts.TextStyleOpts(color="#ddd"),
                min_=0,
                max_=50000000,
            ),
        )
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="400d12488723460e8bcffb1042edf14c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_400d12488723460e8bcffb1042edf14c = echarts.init(
#                     document.getElementById('400d12488723460e8bcffb1042edf14c'), 'white', {renderer: 'canvas'});
#                 var option_400d12488723460e8bcffb1042edf14c = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 44429729.0,
#                 44190255.0,
#                 41843287.0,
#                 39786676.0,
#                 36061539.0,
#                 32748086.0,
#                 30280469.0,
#                 28562128.0,
#                 28526629.0,
#                 22349139.0,
#                 20615162.0,
#                 20501029.0,
#                 20165746.0,
#                 19407358.0,
#                 17716829.0,
#                 16986313.0,
#                 16783218.0,
#                 16529412.0,
#                 15670484.0,
#                 14671334.0,
#                 13081444.0,
#                 12102628.0,
#                 11261732.0,
#                 8907330.0,
#                 7977472.0,
#                 6494676.0,
#                 4832356.0,
#                 3556590.0,
#                 2672876.0,
#                 2333373.0,
#                 1290958.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "max": 50000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c71\u4e1c",
#                 "\u6cb3\u5357",
#                 "\u5e7f\u4e1c",
#                 "\u56db\u5ddd",
#                 "\u6c5f\u82cf",
#                 "\u6cb3\u5317",
#                 "\u6e56\u5357",
#                 "\u5b89\u5fbd",
#                 "\u6e56\u5317",
#                 "\u6d59\u6c5f",
#                 "\u5e7f\u897f",
#                 "\u8fbd\u5b81",
#                 "\u4e91\u5357",
#                 "\u6c5f\u897f",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u9655\u897f",
#                 "\u8d35\u5dde",
#                 "\u798f\u5efa",
#                 "\u5c71\u897f",
#                 "\u91cd\u5e86",
#                 "\u5409\u6797",
#                 "\u7518\u8083",
#                 "\u5185\u8499\u53e4",
#                 "\u65b0\u7586",
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u5929\u6d25",
#                 "\u6d77\u5357",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 50000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_400d12488723460e8bcffb1042edf14c.setOption(option_400d12488723460e8bcffb1042edf14c);
#         });
#     </script>

# %% [markdown]
# #### 每户平均人口数

# %%
c = (
    Map()
    .add(
        "population",
        [list(z) for z in zip(area_list, average_per_house_list)],
        "china"
    )
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_ = 5, min_ = 2.9, is_piecewise=True),
        title_opts=opts.TitleOpts(title="Population_Per_Household_Map_for_2000"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="7048cb17a1f34f6e8fa313b3bee20fd3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_7048cb17a1f34f6e8fa313b3bee20fd3 = echarts.init(
#                     document.getElementById('7048cb17a1f34f6e8fa313b3bee20fd3'), 'white', {renderer: 'canvas'});
#                 var option_7048cb17a1f34f6e8fa313b3bee20fd3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "population",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 2.91
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 3.1
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 3.59
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 3.64
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 3.33
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 3.16
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 3.32
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 3.24
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 2.79
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 3.25
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 3.54
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 3.57
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 3.8
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 3.22
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 3.68
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 3.53
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 3.46
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 3.72
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 3.76
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 4.11
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 3.23
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 3.33
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 3.74
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 3.73
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 4.75
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 3.57
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 3.99
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 3.96
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 3.82
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 3.71
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "population"
#             ],
#             "selected": {
#                 "population": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Population_Per_Household_Map_for_2000",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 2.9,
#         "max": 5,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_7048cb17a1f34f6e8fa313b3bee20fd3.setOption(option_7048cb17a1f34f6e8fa313b3bee20fd3);
#         });
#     </script>

# %%
sorted_area,sorted_average = change_area(area_list,average_per_house_list)
bar = (
        Bar(init_opts=opts.InitOpts(bg_color='rgba(51,51,51)'))
        .add_xaxis(xaxis_data=sorted_area)
        .add_yaxis(
            series_name="",
            y_axis=sorted_average,
            label_opts=opts.LabelOpts(
                is_show=True, position="right", formatter="{b} : {c}"
            ),
        )
        .reversal_axis()
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(
                max_=5, min_ = 2, axislabel_opts=opts.LabelOpts(is_show=False)
            ),
            yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(is_show=False)),
            tooltip_opts=opts.TooltipOpts(is_show=False),
            visualmap_opts=opts.VisualMapOpts(
                is_calculable=True,
                dimension=0,
                pos_left="10",
                pos_top="top",
                range_text=["High", "Low"],
                range_color=["lightskyblue", "yellow", "orangered"],
                textstyle_opts=opts.TextStyleOpts(color="#ddd"),
                min_=2,
                max_=5,
            ),
        )
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5caf9a5ac8c14e01a809aaa1116e80a0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5caf9a5ac8c14e01a809aaa1116e80a0 = echarts.init(
#                     document.getElementById('5caf9a5ac8c14e01a809aaa1116e80a0'), 'white', {renderer: 'canvas'});
#                 var option_5caf9a5ac8c14e01a809aaa1116e80a0 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 4.75,
#                 4.11,
#                 3.99,
#                 3.96,
#                 3.82,
#                 3.8,
#                 3.76,
#                 3.74,
#                 3.73,
#                 3.72,
#                 3.71,
#                 3.68,
#                 3.64,
#                 3.59,
#                 3.57,
#                 3.57,
#                 3.54,
#                 3.53,
#                 3.46,
#                 3.33,
#                 3.33,
#                 3.32,
#                 3.25,
#                 3.24,
#                 3.23,
#                 3.22,
#                 3.16,
#                 3.1,
#                 3.0,
#                 2.91,
#                 2.79
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 2,
#             "max": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u897f\u85cf",
#                 "\u6d77\u5357",
#                 "\u7518\u8083",
#                 "\u9752\u6d77",
#                 "\u5b81\u590f",
#                 "\u6c5f\u897f",
#                 "\u5e7f\u897f",
#                 "\u8d35\u5dde",
#                 "\u4e91\u5357",
#                 "\u5e7f\u4e1c",
#                 "\u65b0\u7586",
#                 "\u6cb3\u5357",
#                 "\u5c71\u897f",
#                 "\u6cb3\u5317",
#                 "\u798f\u5efa",
#                 "\u9655\u897f",
#                 "\u5b89\u5fbd",
#                 "\u6e56\u5317",
#                 "\u6e56\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u56db\u5ddd",
#                 "\u5409\u6797",
#                 "\u6c5f\u82cf",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u91cd\u5e86",
#                 "\u5c71\u4e1c",
#                 "\u8fbd\u5b81",
#                 "\u5929\u6d25",
#                 "\u6d59\u6c5f",
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 2,
#         "max": 5,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_5caf9a5ac8c14e01a809aaa1116e80a0.setOption(option_5caf9a5ac8c14e01a809aaa1116e80a0);
#         });
#     </script>

# %% [markdown]
# ### (2) 外来人口分析

# %%
full_view_path = root_path + 't0104.xls'
data = pd.read_excel(io=full_view_path,header=6).dropna()
data.columns = [i for i in range(16)]
data
# Out:
#           0           1           2           3          4          5   \
# 1        北京市   4637531.0   2552400.0   2085131.0   111952.0    55237.0
# 2        天津市   2181623.0   1141344.0   1040279.0    95093.0    48091.0
# 3        河北省   4881712.0   2615523.0   2266189.0  1379257.0   734839.0
# 4        山西省   3720553.0   2007133.0   1713420.0  1009501.0   532366.0
# 5     内蒙古自治区   3827825.0   1993393.0   1834432.0  1173746.0   585327.0
# 7        辽宁省   6482242.0   3292571.0   3189671.0  1056227.0   527791.0
# 8        吉林省   2949320.0   1505045.0   1444275.0   960959.0   474048.0
# 9       黑龙江省   3768411.0   1924960.0   1843451.0   767182.0   378621.0
# 11       上海市   5384589.0   2888435.0   2496154.0   142138.0    71016.0
# 12       江苏省   9099849.0   4720838.0   4379011.0  2045770.0  1038503.0
# 13       浙江省   8598662.0   4564435.0   4034227.0  1968959.0   984336.0
# 14       安徽省   3558530.0   1865338.0   1693192.0   952144.0   504831.0
# 15       福建省   5911225.0   3176703.0   2734522.0  1159466.0   588907.0
# 16       江西省   3364797.0   1793009.0   1571788.0  1351295.0   730498.0
# 17       山东省   7468014.0   3919980.0   3548034.0  2395731.0  1269588.0
# 19       河南省   5200470.0   2859635.0   2340835.0  1397642.0   763079.0
# 20       湖北省   5704620.0   3028591.0   2676029.0  1374046.0   730264.0
# 21       湖南省   4395720.0   2317758.0   2077962.0  1434086.0   748638.0
# 22       广东省  25304316.0  12682644.0  12621672.0  1945497.0   968875.0
# 23   广西壮族自治区   3234513.0   1674776.0   1559737.0   781045.0   374312.0
# 24       海南省    978148.0    535765.0    442383.0   240443.0   125808.0
# 26       重庆市   2625102.0   1380082.0   1245020.0   670985.0   333219.0
# 27       四川省   6665628.0   3520521.0   3145107.0  2204291.0  1141172.0
# 28       贵州省   2415486.0   1287476.0   1128010.0   622332.0   321284.0
# 29       云南省   3871640.0   2168302.0   1703338.0   758762.0   384330.0
# 30     西藏自治区    213777.0    119621.0     94156.0    36267.0    18404.0
# 32       陕西省   2365334.0   1340506.0   1024828.0   752518.0   419507.0
# 33       甘肃省   1556891.0    867747.0    689144.0   457594.0   251555.0
# 34       青海省    522035.0    288664.0    233371.0   113432.0    59079.0
# 35   宁夏回族自治区    672486.0    360760.0    311726.0   167264.0    84397.0
# 36  新疆维吾尔自治区   2829699.0   1525833.0   1303866.0   728505.0   354956.0
#
#            6          7          8          9          10         11  \
# 1     56715.0  1922063.0   938029.0   984034.0   140299.0    72885.0
# 2     47002.0  1295612.0   636448.0   659164.0    55885.0    27412.0
# 3    644418.0  1370717.0   674143.0   696574.0  1201283.0   669772.0
# 4    477135.0  1251585.0   631775.0   619810.0   792110.0   422998.0
# 5    588419.0   880668.0   435720.0   444948.0  1225488.0   645936.0
# 7    528436.0  3119608.0  1535191.0  1584417.0  1261242.0   635994.0
# 8    486911.0  1044081.0   514070.0   530011.0   635675.0   326254.0
# 9    388561.0  1207507.0   592124.0   615383.0  1407081.0   723937.0
# 11    71122.0   882377.0   434902.0   447475.0  1225152.0   606455.0
# 12  1007267.0  2046696.0  1026481.0  1020215.0  2470494.0  1326695.0
# 13   984623.0  1203420.0   600709.0   602711.0  1737432.0   923356.0
# 14   447313.0  1422743.0   716520.0   706223.0   953527.0   517159.0
# 15   570559.0   944909.0   476276.0   468633.0  1661594.0   884075.0
# 16   620797.0  1005002.0   504256.0   500746.0   755405.0   412043.0
# 17  1126143.0  2385214.0  1218301.0  1166913.0  1653856.0   878981.0
# 19   634563.0  1790969.0   895323.0   895646.0  1535620.0   888531.0
# 20   643782.0  2091710.0  1052859.0  1038851.0  1629131.0   866450.0
# 21   685448.0  1191410.0   598207.0   593203.0  1421386.0   768122.0
# 22   976622.0  2304703.0  1160247.0  1144456.0  5989278.0  3191388.0
# 23   406733.0   610136.0   297099.0   313037.0  1415144.0   746723.0
# 24   114635.0    83591.0    42162.0    41429.0   272322.0   134477.0
# 26   337766.0  1069473.0   549091.0   520382.0   481485.0   271123.0
# 27  1063119.0  1712986.0   864578.0   848408.0  2212105.0  1210262.0
# 28   301048.0   540122.0   265509.0   274613.0   844513.0   446596.0
# 29   374432.0   600639.0   301510.0   299129.0  1347837.0   758329.0
# 30    17863.0    24344.0    11546.0    12798.0    44497.0    20737.0
# 32   333011.0   571842.0   299722.0   272120.0   614945.0   358558.0
# 33   206039.0   382716.0   189223.0   193493.0   488693.0   291289.0
# 34    54353.0   100233.0    48263.0    51970.0   184063.0   103090.0
# 35    82867.0   138830.0    67389.0    71441.0   174501.0    94447.0
# 36   373549.0   184213.0    87628.0    96585.0   505895.0   252880.0
#
#            12          13         14         15
# 1     67414.0   2463217.0  1486249.0   976968.0
# 2     28473.0    735033.0   429393.0   305640.0
# 3    531511.0    930455.0   536769.0   393686.0
# 4    369112.0    667357.0   419994.0   247363.0
# 5    579552.0    547923.0   326410.0   221513.0
# 7    625248.0   1045165.0   593595.0   451570.0
# 8    309421.0    308605.0   190673.0   117932.0
# 9    683144.0    386641.0   230278.0   156363.0
# 11   618697.0   3134922.0  1776062.0  1358860.0
# 12  1143799.0   2536889.0  1329159.0  1207730.0
# 13   814076.0   3688851.0  2056034.0  1632817.0
# 14   436368.0    230116.0   126828.0   103288.0
# 15   777519.0   2145256.0  1227445.0   917811.0
# 16   343362.0    253095.0   146212.0   106883.0
# 17   774875.0   1033213.0   553110.0   480103.0
# 19   647089.0    476239.0   312702.0   163537.0
# 20   762681.0    609733.0   379018.0   230715.0
# 21   653264.0    348838.0   202791.0   146047.0
# 22  2797890.0  15064838.0  7362134.0  7702704.0
# 23   668421.0    428188.0   256642.0   171546.0
# 24   137845.0    381792.0   233318.0   148474.0
# 26   210362.0    403159.0   226649.0   176510.0
# 27  1001843.0    536246.0   304509.0   231737.0
# 28   397917.0    408519.0   254087.0   154432.0
# 29   589508.0   1164402.0   724133.0   440269.0
# 30    23760.0    108669.0    68934.0    39735.0
# 32   256387.0    426029.0   262719.0   163310.0
# 33   197404.0    227888.0   135680.0    92208.0
# 34    80973.0    124307.0    78232.0    46075.0
# 35    80054.0    191891.0   114527.0    77364.0
# 36   253015.0   1411086.0   830369.0   580717.0

# %%
area_list_full = data[0].values.tolist()
area_list = [area[:-1] if area not in change_dict.keys() else change_dict[area] for area in area_list_full]
outside_pop = data[13].values.tolist()

# %%
c = (
    Map()
    .add(
        "population",
        [list(z) for z in zip(area_list, outside_pop)],
        "china"
    )
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_ = 16000000,is_piecewise=True),
        title_opts=opts.TitleOpts(title="Outside_Population_Map_For_2000"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="46d1fec7ff514224a60034cb9a172cb3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_46d1fec7ff514224a60034cb9a172cb3 = echarts.init(
#                     document.getElementById('46d1fec7ff514224a60034cb9a172cb3'), 'white', {renderer: 'canvas'});
#                 var option_46d1fec7ff514224a60034cb9a172cb3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "population",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 2463217.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 735033.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 930455.0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 667357.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 547923.0
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 1045165.0
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 308605.0
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 386641.0
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 3134922.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 2536889.0
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 3688851.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 230116.0
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 2145256.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 253095.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 1033213.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 476239.0
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 609733.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 348838.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 15064838.0
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 428188.0
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 381792.0
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 403159.0
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 536246.0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 408519.0
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 1164402.0
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 108669.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 426029.0
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 227888.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 124307.0
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 191891.0
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 1411086.0
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "population"
#             ],
#             "selected": {
#                 "population": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Outside_Population_Map_For_2000",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 16000000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_46d1fec7ff514224a60034cb9a172cb3.setOption(option_46d1fec7ff514224a60034cb9a172cb3);
#         });
#     </script>

# %%
sorted_area,sorted_out = change_area(area_list,outside_pop)
bar = (
        Bar(init_opts=opts.InitOpts(bg_color='rgba(51,51,51)'))
        .add_xaxis(xaxis_data=sorted_area)
        .add_yaxis(
            series_name="",
            y_axis=sorted_out,
            label_opts=opts.LabelOpts(
                is_show=True, position="right", formatter="{b} : {c}"
            ),
        )
        .reversal_axis()
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(
                max_=20000000, min_ = 0, axislabel_opts=opts.LabelOpts(is_show=False)
            ),
            yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(is_show=False)),
            tooltip_opts=opts.TooltipOpts(is_show=False),
            visualmap_opts=opts.VisualMapOpts(
                is_calculable=True,
                dimension=0,
                pos_left="10",
                pos_top="top",
                range_text=["High", "Low"],
                range_color=["lightskyblue", "yellow", "orangered"],
                textstyle_opts=opts.TextStyleOpts(color="#ddd"),
                min_=0,
                max_=16000000,
            ),
        )
    )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="60b5a27dadff4dcf9aeb535eaa11eb84" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_60b5a27dadff4dcf9aeb535eaa11eb84 = echarts.init(
#                     document.getElementById('60b5a27dadff4dcf9aeb535eaa11eb84'), 'white', {renderer: 'canvas'});
#                 var option_60b5a27dadff4dcf9aeb535eaa11eb84 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 15064838.0,
#                 3688851.0,
#                 3134922.0,
#                 2536889.0,
#                 2463217.0,
#                 2145256.0,
#                 1411086.0,
#                 1164402.0,
#                 1045165.0,
#                 1033213.0,
#                 930455.0,
#                 735033.0,
#                 667357.0,
#                 609733.0,
#                 547923.0,
#                 536246.0,
#                 476239.0,
#                 428188.0,
#                 426029.0,
#                 408519.0,
#                 403159.0,
#                 386641.0,
#                 381792.0,
#                 348838.0,
#                 308605.0,
#                 253095.0,
#                 230116.0,
#                 227888.0,
#                 191891.0,
#                 124307.0,
#                 108669.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 20000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e7f\u4e1c",
#                 "\u6d59\u6c5f",
#                 "\u4e0a\u6d77",
#                 "\u6c5f\u82cf",
#                 "\u5317\u4eac",
#                 "\u798f\u5efa",
#                 "\u65b0\u7586",
#                 "\u4e91\u5357",
#                 "\u8fbd\u5b81",
#                 "\u5c71\u4e1c",
#                 "\u6cb3\u5317",
#                 "\u5929\u6d25",
#                 "\u5c71\u897f",
#                 "\u6e56\u5317",
#                 "\u5185\u8499\u53e4",
#                 "\u56db\u5ddd",
#                 "\u6cb3\u5357",
#                 "\u5e7f\u897f",
#                 "\u9655\u897f",
#                 "\u8d35\u5dde",
#                 "\u91cd\u5e86",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u6d77\u5357",
#                 "\u6e56\u5357",
#                 "\u5409\u6797",
#                 "\u6c5f\u897f",
#                 "\u5b89\u5fbd",
#                 "\u7518\u8083",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 16000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_60b5a27dadff4dcf9aeb535eaa11eb84.setOption(option_60b5a27dadff4dcf9aeb535eaa11eb84);
#         });
#     </script>

# %% [markdown]
# #### 受教育情况

# %%
full_view_path = root_path + 't0108.xls'
data = pd.read_excel(io=full_view_path,header=6).dropna()
data.columns = [i for i in range(31)]
data
# Out:
#           0           1           2           3          4          5   \
# 1        北京市  13023990.0   6788237.0   6235753.0   581637.0   127773.0
# 2        天津市   9381201.0   4768665.0   4612536.0   513821.0   118661.0
# 3        河北省  62335115.0  31608495.0  30726620.0  3746461.0  1318509.0
# 4        山西省  29741362.0  15367303.0  14374059.0  1543364.0   494072.0
# 5     内蒙古自治区  21834015.0  11283138.0  10550877.0  2186638.0   702262.0
# 7        辽宁省  39632542.0  20160932.0  19471610.0  2117529.0   585083.0
# 8        吉林省  25474107.0  13022912.0  12451195.0  1342416.0   435421.0
# 9       黑龙江省  34329762.0  17527645.0  16802117.0  1968874.0   612375.0
# 11       上海市  15806710.0   8115345.0   7691365.0   873696.0   176195.0
# 12       江苏省  69220051.0  34873894.0  34346157.0  4585521.0  1036621.0
# 13       浙江省  43119938.0  22085771.0  21034167.0  3212522.0   852021.0
# 14       安徽省  54781525.0  28063891.0  26717634.0  5937345.0  1728191.0
# 15       福建省  32031728.0  16422417.0  15609311.0  2390826.0   720366.0
# 16       江西省  37026619.0  19076290.0  17950329.0  2147384.0   515989.0
# 17       山东省  84523711.0  42634962.0  41888749.0  7617518.0  1996728.0
# 19       河南省  84816733.0  43398922.0  41417811.0  5428858.0  1513313.0
# 20       湖北省  56343167.0  29198887.0  27144280.0  4321859.0  1085383.0
# 21       湖南省  59397047.0  30851289.0  28545758.0  2982232.0   724619.0
# 22       广东省  78197935.0  39446597.0  38751338.0  3897970.0   870643.0
# 23   广西壮族自治区  40401357.0  21304389.0  19096968.0  1916084.0   468488.0
# 24       海南省   6890266.0   3620076.0   3270190.0   581837.0   138999.0
# 26       重庆市  28254314.0  14627840.0  13626474.0  2173652.0   597068.0
# 27       四川省  76182542.0  39265346.0  36917196.0  6608326.0  1917817.0
# 28       贵州省  31285200.0  16353147.0  14932053.0  5256778.0  1433498.0
# 29       云南省  38226672.0  20001247.0  18225425.0  5157800.0  1684579.0
# 30     西藏自治区   2310307.0   1171148.0   1139159.0  1071534.0   417859.0
# 32       陕西省  33018083.0  17074459.0  15943624.0  2667730.0   803434.0
# 33       甘肃省  23013261.0  11878583.0  11134678.0  3881068.0  1254145.0
# 34       青海省   4360863.0   2249218.0   2111645.0  1031333.0   347262.0
# 35   宁夏回族自治区   4931879.0   2524596.0   2407283.0   659270.0   208944.0
# 36  新疆维吾尔自治区  16808291.0   8704037.0   8104254.0  1227553.0   500626.0
#
#            6          7         8          9   ...         21         22  \
# 1    453864.0    47255.0   13966.0    33289.0  ...   511935.0  1029929.0
# 2    395160.0    52641.0   15108.0    37533.0  ...   411906.0   506548.0
# 3   2427952.0  1391599.0  567625.0   823974.0  ...   965771.0  1241219.0
# 4   1049292.0   367239.0  125764.0   241475.0  ...   571939.0   784075.0
# 5   1484376.0   166045.0   62535.0   103510.0  ...   424856.0   648891.0
# 7   1532446.0   171572.0   54933.0   116639.0  ...   777309.0  1692445.0
# 8    906995.0   189862.0   69127.0   120735.0  ...   512322.0   813292.0
# 9   1356499.0   147023.0   52682.0    94341.0  ...   613537.0  1199694.0
# 11   697501.0   216143.0   49493.0   166650.0  ...   586702.0   934083.0
# 12  3548900.0  1638610.0  396757.0  1241853.0  ...  1027994.0  1857521.0
# 13  2360501.0  1333150.0  409988.0   923162.0  ...   563320.0   955955.0
# 14  4209154.0  1553752.0  458069.0  1095683.0  ...   663085.0   921539.0
# 15  1670460.0   687304.0  148881.0   538423.0  ...   584581.0   664183.0
# 16  1631395.0   732457.0  168495.0   563962.0  ...   473684.0   729694.0
# 17  5620790.0  1515741.0  459844.0  1055897.0  ...  1549432.0  2040572.0
# 19  3915545.0  1500232.0  482662.0  1017570.0  ...  1167167.0  1817134.0
# 20  3236476.0   694959.0  203765.0   491194.0  ...  1109001.0  1537447.0
# 21  2257613.0   676936.0  204273.0   472663.0  ...   960800.0  1314744.0
# 22  3027327.0   764560.0  184579.0   579981.0  ...  1395321.0  2046311.0
# 23  1447596.0   572529.0  134350.0   438179.0  ...   688833.0   759650.0
# 24   442838.0    68032.0   18590.0    49442.0  ...   109021.0   167622.0
# 26  1576584.0   373654.0  119384.0   254270.0  ...   344822.0   555971.0
# 27  4690509.0  1664134.0  560838.0  1103296.0  ...   965112.0  1372692.0
# 28  3823280.0   729043.0  176602.0   552441.0  ...   369649.0   464897.0
# 29  3473221.0  1430405.0  426477.0  1003928.0  ...   513828.0   576877.0
# 30   653675.0   149969.0   86224.0    63745.0  ...    20826.0    23255.0
# 32  1864296.0   609044.0  192821.0   416223.0  ...   510703.0   914224.0
# 33  2626923.0   670490.0  221922.0   448568.0  ...   301520.0   467959.0
# 34   684071.0   155677.0   56686.0    98991.0  ...    68865.0   109100.0
# 35   450326.0   194625.0   59971.0   134654.0  ...    81424.0   136967.0
# 36   726927.0   302613.0  145586.0   157027.0  ...   418073.0   700996.0
#
#            23        24         25        26        27        28        29  \
# 1    522487.0  507442.0  1082268.0  621697.0  460571.0  172653.0  114011.0
# 2    273693.0  232855.0   355426.0  210338.0  145088.0   24040.0   15430.0
# 3    694453.0  546766.0   539833.0  330894.0  208939.0   18020.0   12153.0
# 4    449507.0  334568.0   314548.0  195122.0  119426.0   12452.0    7946.0
# 5    363494.0  285397.0   234087.0  141821.0   92266.0    6851.0    4368.0
# 7    923053.0  769392.0   845654.0  513277.0  332377.0   47251.0   30942.0
# 8    451474.0  361818.0   486979.0  290865.0  196114.0   21600.0   13499.0
# 9    665200.0  534494.0   517847.0  313571.0  204276.0   24013.0   15856.0
# 11   537926.0  396157.0   784698.0  493142.0  291556.0   76188.0   53249.0
# 12  1168251.0  689270.0   946584.0  644092.0  302492.0   58165.0   42855.0
# 13   576482.0  379473.0   481679.0  322433.0  159246.0   30227.0   22774.0
# 14   613354.0  308185.0   425264.0  313771.0  111493.0   17108.0   13290.0
# 15   437142.0  227041.0   331621.0  236405.0   95216.0   15927.0   11575.0
# 16   492736.0  236958.0   306352.0  221269.0   85083.0    8713.0    6489.0
# 17  1254109.0  786463.0   921054.0  618318.0  302736.0   39126.0   27612.0
# 19  1081853.0  735281.0   600731.0  400610.0  200121.0   21656.0   15839.0
# 20   959347.0  578100.0   729583.0  492992.0  236591.0   53623.0   38420.0
# 21   817841.0  496903.0   511717.0  353282.0  158435.0   25229.0   18817.0
# 22  1265235.0  781076.0   907391.0  613595.0  293796.0   77621.0   57434.0
# 23   479282.0  280368.0   275918.0  194364.0   81554.0   11566.0    8320.0
# 24   114355.0   53267.0    68398.0   48715.0   19683.0    4343.0    3349.0
# 26   331336.0  224635.0   289664.0  192366.0   97298.0   14440.0   10439.0
# 27   831393.0  541299.0   629175.0  424182.0  204993.0   36787.0   26396.0
# 28   292252.0  172645.0   205791.0  140499.0   65292.0    4178.0    3006.0
# 29   356731.0  220146.0   263694.0  172963.0   90731.0   11988.0    8491.0
# 30    15000.0    8255.0     9962.0    6602.0    3360.0     340.0     293.0
# 32   542184.0  372040.0   539222.0  354269.0  184953.0   32597.0   22510.0
# 33   296262.0  171697.0   195449.0  135570.0   59879.0    9007.0    6276.0
# 34    63964.0   45136.0    46396.0   30476.0   15920.0     938.0     690.0
# 35    80564.0   56403.0    64438.0   41369.0   23069.0    1124.0     791.0
# 36   369798.0  331198.0   239303.0  139893.0   99410.0    6162.0    4132.0
#
#          30
# 1   58642.0
# 2    8610.0
# 3    5867.0
# 4    4506.0
# 5    2483.0
# 7   16309.0
# 8    8101.0
# 9    8157.0
# 11  22939.0
# 12  15310.0
# 13   7453.0
# 14   3818.0
# 15   4352.0
# 16   2224.0
# 17  11514.0
# 19   5817.0
# 20  15203.0
# 21   6412.0
# 22  20187.0
# 23   3246.0
# 24    994.0
# 26   4001.0
# 27  10391.0
# 28   1172.0
# 29   3497.0
# 30     47.0
# 32  10087.0
# 33   2731.0
# 34    248.0
# 35    333.0
# 36   2030.0
#
# [31 rows x 31 columns]

# %%
area_list_full = data[0].values.tolist()
area_list = [area[:-1] if area not in change_dict.keys() else change_dict[area] for area in area_list_full]
no_school = data[4].values.tolist()
literacy = data[7].values.tolist()
primary = data[10].values.tolist()
middle = data[13].values.tolist()
high = data[16].values.tolist()
tech = data[19].values.tolist()
junior = data[22].values.tolist()
university = data[25].values.tolist()
MBA = data[28].values.tolist()

# %%
c = (
    Map()
    .add(
        "no_school",
        [list(z) for z in zip(area_list, no_school)],
        "china"
    )
    .add(
        "literacy",
        [list(z) for z in zip(area_list, literacy)],
        "china"
    )
    .add(
        "primary",
        [list(z) for z in zip(area_list, primary)],
        "china"
    )
    .add(
        "middle",
        [list(z) for z in zip(area_list, middle)],
        "china"
    )
    .add(
        "high",
        [list(z) for z in zip(area_list, high)],
        "china"
    )
    .add(
        "tech",
        [list(z) for z in zip(area_list, tech)],
        "china"
    )
    .add(
        "junior",
        [list(z) for z in zip(area_list, junior)],
        "china"
    )
    .add(
        "university",
        [list(z) for z in zip(area_list, university)],
        "china"
    )
    .add(
        "MBA",
        [list(z) for z in zip(area_list, MBA)],
        "china"
    )
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_ = 20000000,is_piecewise=True),
        title_opts=opts.TitleOpts(title="2000"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="37079230d1ad4029809194a0469b9f98" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_37079230d1ad4029809194a0469b9f98 = echarts.init(
#                     document.getElementById('37079230d1ad4029809194a0469b9f98'), 'white', {renderer: 'canvas'});
#                 var option_37079230d1ad4029809194a0469b9f98 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "no_school",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 581637.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 513821.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 3746461.0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 1543364.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 2186638.0
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 2117529.0
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 1342416.0
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 1968874.0
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 873696.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 4585521.0
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 3212522.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 5937345.0
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 2390826.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 2147384.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 7617518.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 5428858.0
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 4321859.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 2982232.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 3897970.0
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 1916084.0
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 581837.0
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 2173652.0
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 6608326.0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 5256778.0
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 5157800.0
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1071534.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 2667730.0
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 3881068.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1031333.0
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 659270.0
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 1227553.0
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         },
#         {
#             "type": "map",
#             "name": "literacy",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 47255.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 52641.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 1391599.0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 367239.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 166045.0
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 171572.0
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 189862.0
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 147023.0
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 216143.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 1638610.0
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1333150.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 1553752.0
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 687304.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 732457.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 1515741.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1500232.0
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 694959.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",

# %%
def draw_bar(area_list, value_list, max_num = 1000000):
    sorted_area,sorted_out = change_area(area_list,value_list)
    bar = (
            Bar(init_opts=opts.InitOpts(bg_color='rgba(51,51,51)'))
            .add_xaxis(xaxis_data=sorted_area)
            .add_yaxis(
                series_name="",
                y_axis=sorted_out,
                label_opts=opts.LabelOpts(
                    is_show=True, position="right", formatter="{b} : {c}"
                ),
            )
            .reversal_axis()
            .set_global_opts(
                xaxis_opts=opts.AxisOpts(
                    max_=max_num, min_ = 0, axislabel_opts=opts.LabelOpts(is_show=False)
                ),
                yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(is_show=False)),
                tooltip_opts=opts.TooltipOpts(is_show=False),
                visualmap_opts=opts.VisualMapOpts(
                    is_calculable=True,
                    dimension=0,
                    pos_left="10",
                    pos_top="top",
                    range_text=["High", "Low"],
                    range_color=["lightskyblue", "yellow", "orangered"],
                    textstyle_opts=opts.TextStyleOpts(color="#ddd"),
                    min_=0,
                    max_=max_num,
                ),
            )
        )

    return bar

# %%
bar = draw_bar(area_list, no_school, 8000000)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ea5d08868a234ef9a7533d58bf20c687" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ea5d08868a234ef9a7533d58bf20c687 = echarts.init(
#                     document.getElementById('ea5d08868a234ef9a7533d58bf20c687'), 'white', {renderer: 'canvas'});
#                 var option_ea5d08868a234ef9a7533d58bf20c687 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 7617518.0,
#                 6608326.0,
#                 5937345.0,
#                 5428858.0,
#                 5256778.0,
#                 5157800.0,
#                 4585521.0,
#                 4321859.0,
#                 3897970.0,
#                 3881068.0,
#                 3746461.0,
#                 3212522.0,
#                 2982232.0,
#                 2667730.0,
#                 2390826.0,
#                 2186638.0,
#                 2173652.0,
#                 2147384.0,
#                 2117529.0,
#                 1968874.0,
#                 1916084.0,
#                 1543364.0,
#                 1342416.0,
#                 1227553.0,
#                 1071534.0,
#                 1031333.0,
#                 873696.0,
#                 659270.0,
#                 581837.0,
#                 581637.0,
#                 513821.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 8000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c71\u4e1c",
#                 "\u56db\u5ddd",
#                 "\u5b89\u5fbd",
#                 "\u6cb3\u5357",
#                 "\u8d35\u5dde",
#                 "\u4e91\u5357",
#                 "\u6c5f\u82cf",
#                 "\u6e56\u5317",
#                 "\u5e7f\u4e1c",
#                 "\u7518\u8083",
#                 "\u6cb3\u5317",
#                 "\u6d59\u6c5f",
#                 "\u6e56\u5357",
#                 "\u9655\u897f",
#                 "\u798f\u5efa",
#                 "\u5185\u8499\u53e4",
#                 "\u91cd\u5e86",
#                 "\u6c5f\u897f",
#                 "\u8fbd\u5b81",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5e7f\u897f",
#                 "\u5c71\u897f",
#                 "\u5409\u6797",
#                 "\u65b0\u7586",
#                 "\u897f\u85cf",
#                 "\u9752\u6d77",
#                 "\u4e0a\u6d77",
#                 "\u5b81\u590f",
#                 "\u6d77\u5357",
#                 "\u5317\u4eac",
#                 "\u5929\u6d25"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 8000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_ea5d08868a234ef9a7533d58bf20c687.setOption(option_ea5d08868a234ef9a7533d58bf20c687);
#         });
#     </script>

# %%
bar = draw_bar(area_list, literacy, 2000000)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2ebb79aa3e5a411fa02efc5543d52194" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2ebb79aa3e5a411fa02efc5543d52194 = echarts.init(
#                     document.getElementById('2ebb79aa3e5a411fa02efc5543d52194'), 'white', {renderer: 'canvas'});
#                 var option_2ebb79aa3e5a411fa02efc5543d52194 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 1664134.0,
#                 1638610.0,
#                 1553752.0,
#                 1515741.0,
#                 1500232.0,
#                 1430405.0,
#                 1391599.0,
#                 1333150.0,
#                 764560.0,
#                 732457.0,
#                 729043.0,
#                 694959.0,
#                 687304.0,
#                 676936.0,
#                 670490.0,
#                 609044.0,
#                 572529.0,
#                 373654.0,
#                 367239.0,
#                 302613.0,
#                 216143.0,
#                 194625.0,
#                 189862.0,
#                 171572.0,
#                 166045.0,
#                 155677.0,
#                 149969.0,
#                 147023.0,
#                 68032.0,
#                 52641.0,
#                 47255.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 2000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u56db\u5ddd",
#                 "\u6c5f\u82cf",
#                 "\u5b89\u5fbd",
#                 "\u5c71\u4e1c",
#                 "\u6cb3\u5357",
#                 "\u4e91\u5357",
#                 "\u6cb3\u5317",
#                 "\u6d59\u6c5f",
#                 "\u5e7f\u4e1c",
#                 "\u6c5f\u897f",
#                 "\u8d35\u5dde",
#                 "\u6e56\u5317",
#                 "\u798f\u5efa",
#                 "\u6e56\u5357",
#                 "\u7518\u8083",
#                 "\u9655\u897f",
#                 "\u5e7f\u897f",
#                 "\u91cd\u5e86",
#                 "\u5c71\u897f",
#                 "\u65b0\u7586",
#                 "\u4e0a\u6d77",
#                 "\u5b81\u590f",
#                 "\u5409\u6797",
#                 "\u8fbd\u5b81",
#                 "\u5185\u8499\u53e4",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u6d77\u5357",
#                 "\u5929\u6d25",
#                 "\u5317\u4eac"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 2000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_2ebb79aa3e5a411fa02efc5543d52194.setOption(option_2ebb79aa3e5a411fa02efc5543d52194);
#         });
#     </script>

# %%
bar = draw_bar(area_list, primary, 40000000)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2345c2dab05d4a01ac5b80eb3afbb629" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2345c2dab05d4a01ac5b80eb3afbb629 = echarts.init(
#                     document.getElementById('2345c2dab05d4a01ac5b80eb3afbb629'), 'white', {renderer: 'canvas'});
#                 var option_2345c2dab05d4a01ac5b80eb3afbb629 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 35379826.0,
#                 30321740.0,
#                 29469811.0,
#                 28224273.0,
#                 24219937.0,
#                 24017994.0,
#                 22135051.0,
#                 22043367.0,
#                 21081800.0,
#                 18979254.0,
#                 18432526.0,
#                 16833356.0,
#                 15660576.0,
#                 15352997.0,
#                 13229559.0,
#                 12875533.0,
#                 12482572.0,
#                 12178915.0,
#                 11328284.0,
#                 10319110.0,
#                 9280811.0,
#                 8997647.0,
#                 7261714.0,
#                 6997824.0,
#                 3106637.0,
#                 2598636.0,
#                 2468891.0,
#                 2301726.0,
#                 1747141.0,
#                 1489401.0,
#                 796442.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 40000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u56db\u5ddd",
#                 "\u6cb3\u5357",
#                 "\u5c71\u4e1c",
#                 "\u5e7f\u4e1c",
#                 "\u6e56\u5357",
#                 "\u6c5f\u82cf",
#                 "\u6cb3\u5317",
#                 "\u5b89\u5fbd",
#                 "\u6e56\u5317",
#                 "\u4e91\u5357",
#                 "\u5e7f\u897f",
#                 "\u6d59\u6c5f",
#                 "\u6c5f\u897f",
#                 "\u8d35\u5dde",
#                 "\u91cd\u5e86",
#                 "\u798f\u5efa",
#                 "\u8fbd\u5b81",
#                 "\u9655\u897f",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5c71\u897f",
#                 "\u7518\u8083",
#                 "\u5409\u6797",
#                 "\u5185\u8499\u53e4",
#                 "\u65b0\u7586",
#                 "\u4e0a\u6d77",
#                 "\u6d77\u5357",
#                 "\u5929\u6d25",
#                 "\u5317\u4eac",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 40000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_2345c2dab05d4a01ac5b80eb3afbb629.setOption(option_2345c2dab05d4a01ac5b80eb3afbb629);
#         });
#     </script>

# %%
bar = draw_bar(area_list, middle, 40000000)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e59c41ca6a244a27ba6fbbf91c200716" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e59c41ca6a244a27ba6fbbf91c200716 = echarts.init(
#                     document.getElementById('e59c41ca6a244a27ba6fbbf91c200716'), 'white', {renderer: 'canvas'});
#                 var option_e59c41ca6a244a27ba6fbbf91c200716 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 35919247.0,
#                 32973455.0,
#                 31261428.0,
#                 26562474.0,
#                 26099323.0,
#                 24193763.0,
#                 22593804.0,
#                 20398435.0,
#                 19367607.0,
#                 16757863.0,
#                 15319423.0,
#                 14218494.0,
#                 14113200.0,
#                 13455575.0,
#                 12637984.0,
#                 11707710.0,
#                 11437732.0,
#                 9567968.0,
#                 9018044.0,
#                 8993338.0,
#                 8116632.0,
#                 7274827.0,
#                 6038572.0,
#                 6017876.0,
#                 5085927.0,
#                 4665166.0,
#                 3405530.0,
#                 2455575.0,
#                 1528441.0,
#                 1035237.0,
#                 165957.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 40000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u5357",
#                 "\u5c71\u4e1c",
#                 "\u5e7f\u4e1c",
#                 "\u6c5f\u82cf",
#                 "\u6cb3\u5317",
#                 "\u56db\u5ddd",
#                 "\u6e56\u5357",
#                 "\u6e56\u5317",
#                 "\u5b89\u5fbd",
#                 "\u8fbd\u5b81",
#                 "\u6d59\u6c5f",
#                 "\u5e7f\u897f",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u6c5f\u897f",
#                 "\u5c71\u897f",
#                 "\u9655\u897f",
#                 "\u798f\u5efa",
#                 "\u5409\u6797",
#                 "\u4e91\u5357",
#                 "\u91cd\u5e86",
#                 "\u5185\u8499\u53e4",
#                 "\u8d35\u5dde",
#                 "\u4e0a\u6d77",
#                 "\u7518\u8083",
#                 "\u65b0\u7586",
#                 "\u5317\u4eac",
#                 "\u5929\u6d25",
#                 "\u6d77\u5357",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 40000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_e59c41ca6a244a27ba6fbbf91c200716.setOption(option_e59c41ca6a244a27ba6fbbf91c200716);
#         });
#     </script>

# %%
bar = draw_bar(area_list, high, 9000000)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3f88cbf023df4e79afa97881da4a3915" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3f88cbf023df4e79afa97881da4a3915 = echarts.init(
#                     document.getElementById('3f88cbf023df4e79afa97881da4a3915'), 'white', {renderer: 'canvas'});
#                 var option_3f88cbf023df4e79afa97881da4a3915 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 8181919.0,
#                 7432762.0,
#                 6935346.0,
#                 6750446.0,
#                 5317893.0,
#                 5197580.0,
#                 5123301.0,
#                 4268063.0,
#                 3997787.0,
#                 3848613.0,
#                 3834472.0,
#                 3307017.0,
#                 3084848.0,
#                 3057145.0,
#                 2946204.0,
#                 2787826.0,
#                 2665497.0,
#                 2659168.0,
#                 2442143.0,
#                 2331910.0,
#                 2197285.0,
#                 1897989.0,
#                 1818727.0,
#                 1657168.0,
#                 1415358.0,
#                 1261461.0,
#                 1137569.0,
#                 707116.0,
#                 426233.0,
#                 342581.0,
#                 42418.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 9000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e7f\u4e1c",
#                 "\u6c5f\u82cf",
#                 "\u6cb3\u5357",
#                 "\u5c71\u4e1c",
#                 "\u6cb3\u5317",
#                 "\u6e56\u5317",
#                 "\u6e56\u5357",
#                 "\u56db\u5ddd",
#                 "\u8fbd\u5b81",
#                 "\u6d59\u6c5f",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u9655\u897f",
#                 "\u5b89\u5fbd",
#                 "\u5409\u6797",
#                 "\u6c5f\u897f",
#                 "\u5e7f\u897f",
#                 "\u4e0a\u6d77",
#                 "\u5c71\u897f",
#                 "\u798f\u5efa",
#                 "\u5185\u8499\u53e4",
#                 "\u5317\u4eac",
#                 "\u91cd\u5e86",
#                 "\u7518\u8083",
#                 "\u4e91\u5357",
#                 "\u65b0\u7586",
#                 "\u5929\u6d25",
#                 "\u8d35\u5dde",
#                 "\u6d77\u5357",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 9000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_3f88cbf023df4e79afa97881da4a3915.setOption(option_3f88cbf023df4e79afa97881da4a3915);
#         });
#     </script>

# %%
bar = draw_bar(area_list, tech, 4000000)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="93c54addcc6f4fd1abbb8fe5bdedd491" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_93c54addcc6f4fd1abbb8fe5bdedd491 = echarts.init(
#                     document.getElementById('93c54addcc6f4fd1abbb8fe5bdedd491'), 'white', {renderer: 'canvas'});
#                 var option_93c54addcc6f4fd1abbb8fe5bdedd491 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 3195988.0,
#                 2836462.0,
#                 2327881.0,
#                 2271789.0,
#                 2120420.0,
#                 2029776.0,
#                 1949147.0,
#                 1845716.0,
#                 1519869.0,
#                 1430695.0,
#                 1426764.0,
#                 1196355.0,
#                 1186459.0,
#                 1131442.0,
#                 1111196.0,
#                 1105013.0,
#                 1103422.0,
#                 1061624.0,
#                 1039664.0,
#                 997198.0,
#                 946071.0,
#                 881247.0,
#                 859120.0,
#                 832555.0,
#                 792843.0,
#                 726047.0,
#                 671874.0,
#                 238707.0,
#                 173640.0,
#                 150200.0,
#                 50430.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 4000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c71\u4e1c",
#                 "\u5e7f\u4e1c",
#                 "\u6e56\u5317",
#                 "\u6cb3\u5357",
#                 "\u6c5f\u82cf",
#                 "\u56db\u5ddd",
#                 "\u6e56\u5357",
#                 "\u6cb3\u5317",
#                 "\u8fbd\u5b81",
#                 "\u5b89\u5fbd",
#                 "\u5e7f\u897f",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u798f\u5efa",
#                 "\u4e91\u5357",
#                 "\u4e0a\u6d77",
#                 "\u6d59\u6c5f",
#                 "\u5c71\u897f",
#                 "\u9655\u897f",
#                 "\u6c5f\u897f",
#                 "\u5409\u6797",
#                 "\u5317\u4eac",
#                 "\u5185\u8499\u53e4",
#                 "\u8d35\u5dde",
#                 "\u65b0\u7586",
#                 "\u5929\u6d25",
#                 "\u91cd\u5e86",
#                 "\u7518\u8083",
#                 "\u6d77\u5357",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 4000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_93c54addcc6f4fd1abbb8fe5bdedd491.setOption(option_93c54addcc6f4fd1abbb8fe5bdedd491);
#         });
#     </script>

# %%
bar = draw_bar(area_list, junior, 2000000)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="614a1264a7254789bc93068fa45fd374" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_614a1264a7254789bc93068fa45fd374 = echarts.init(
#                     document.getElementById('614a1264a7254789bc93068fa45fd374'), 'white', {renderer: 'canvas'});
#                 var option_614a1264a7254789bc93068fa45fd374 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 2046311.0,
#                 2040572.0,
#                 1857521.0,
#                 1817134.0,
#                 1692445.0,
#                 1537447.0,
#                 1372692.0,
#                 1314744.0,
#                 1241219.0,
#                 1199694.0,
#                 1029929.0,
#                 955955.0,
#                 934083.0,
#                 921539.0,
#                 914224.0,
#                 813292.0,
#                 784075.0,
#                 759650.0,
#                 729694.0,
#                 700996.0,
#                 664183.0,
#                 648891.0,
#                 576877.0,
#                 555971.0,
#                 506548.0,
#                 467959.0,
#                 464897.0,
#                 167622.0,
#                 136967.0,
#                 109100.0,
#                 23255.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 2000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e7f\u4e1c",
#                 "\u5c71\u4e1c",
#                 "\u6c5f\u82cf",
#                 "\u6cb3\u5357",
#                 "\u8fbd\u5b81",
#                 "\u6e56\u5317",
#                 "\u56db\u5ddd",
#                 "\u6e56\u5357",
#                 "\u6cb3\u5317",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5317\u4eac",
#                 "\u6d59\u6c5f",
#                 "\u4e0a\u6d77",
#                 "\u5b89\u5fbd",
#                 "\u9655\u897f",
#                 "\u5409\u6797",
#                 "\u5c71\u897f",
#                 "\u5e7f\u897f",
#                 "\u6c5f\u897f",
#                 "\u65b0\u7586",
#                 "\u798f\u5efa",
#                 "\u5185\u8499\u53e4",
#                 "\u4e91\u5357",
#                 "\u91cd\u5e86",
#                 "\u5929\u6d25",
#                 "\u7518\u8083",
#                 "\u8d35\u5dde",
#                 "\u6d77\u5357",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 2000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_614a1264a7254789bc93068fa45fd374.setOption(option_614a1264a7254789bc93068fa45fd374);
#         });
#     </script>

# %%
bar = draw_bar(area_list, university, 2000000)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c22a8fb4ba8946d2a2575c0dc4efb07f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c22a8fb4ba8946d2a2575c0dc4efb07f = echarts.init(
#                     document.getElementById('c22a8fb4ba8946d2a2575c0dc4efb07f'), 'white', {renderer: 'canvas'});
#                 var option_c22a8fb4ba8946d2a2575c0dc4efb07f = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 1082268.0,
#                 946584.0,
#                 921054.0,
#                 907391.0,
#                 845654.0,
#                 784698.0,
#                 729583.0,
#                 629175.0,
#                 600731.0,
#                 539833.0,
#                 539222.0,
#                 517847.0,
#                 511717.0,
#                 486979.0,
#                 481679.0,
#                 425264.0,
#                 355426.0,
#                 331621.0,
#                 314548.0,
#                 306352.0,
#                 289664.0,
#                 275918.0,
#                 263694.0,
#                 239303.0,
#                 234087.0,
#                 205791.0,
#                 195449.0,
#                 68398.0,
#                 64438.0,
#                 46396.0,
#                 9962.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 2000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac",
#                 "\u6c5f\u82cf",
#                 "\u5c71\u4e1c",
#                 "\u5e7f\u4e1c",
#                 "\u8fbd\u5b81",
#                 "\u4e0a\u6d77",
#                 "\u6e56\u5317",
#                 "\u56db\u5ddd",
#                 "\u6cb3\u5357",
#                 "\u6cb3\u5317",
#                 "\u9655\u897f",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u6e56\u5357",
#                 "\u5409\u6797",
#                 "\u6d59\u6c5f",
#                 "\u5b89\u5fbd",
#                 "\u5929\u6d25",
#                 "\u798f\u5efa",
#                 "\u5c71\u897f",
#                 "\u6c5f\u897f",
#                 "\u91cd\u5e86",
#                 "\u5e7f\u897f",
#                 "\u4e91\u5357",
#                 "\u65b0\u7586",
#                 "\u5185\u8499\u53e4",
#                 "\u8d35\u5dde",
#                 "\u7518\u8083",
#                 "\u6d77\u5357",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 2000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_c22a8fb4ba8946d2a2575c0dc4efb07f.setOption(option_c22a8fb4ba8946d2a2575c0dc4efb07f);
#         });
#     </script>

# %%
bar = draw_bar(area_list, MBA, 2000000)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4e889744aeb141ecbef8bb0f653a1549" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4e889744aeb141ecbef8bb0f653a1549 = echarts.init(
#                     document.getElementById('4e889744aeb141ecbef8bb0f653a1549'), 'white', {renderer: 'canvas'});
#                 var option_4e889744aeb141ecbef8bb0f653a1549 = {
#     "backgroundColor": "rgba(51,51,51)",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 172653.0,
#                 77621.0,
#                 76188.0,
#                 58165.0,
#                 53623.0,
#                 47251.0,
#                 39126.0,
#                 36787.0,
#                 32597.0,
#                 30227.0,
#                 25229.0,
#                 24040.0,
#                 24013.0,
#                 21656.0,
#                 21600.0,
#                 18020.0,
#                 17108.0,
#                 15927.0,
#                 14440.0,
#                 12452.0,
#                 11988.0,
#                 11566.0,
#                 9007.0,
#                 8713.0,
#                 6851.0,
#                 6162.0,
#                 4343.0,
#                 4178.0,
#                 1124.0,
#                 938.0,
#                 340.0
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{b} : {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 2000000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac",
#                 "\u5e7f\u4e1c",
#                 "\u4e0a\u6d77",
#                 "\u6c5f\u82cf",
#                 "\u6e56\u5317",
#                 "\u8fbd\u5b81",
#                 "\u5c71\u4e1c",
#                 "\u56db\u5ddd",
#                 "\u9655\u897f",
#                 "\u6d59\u6c5f",
#                 "\u6e56\u5357",
#                 "\u5929\u6d25",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u6cb3\u5357",
#                 "\u5409\u6797",
#                 "\u6cb3\u5317",
#                 "\u5b89\u5fbd",
#                 "\u798f\u5efa",
#                 "\u91cd\u5e86",
#                 "\u5c71\u897f",
#                 "\u4e91\u5357",
#                 "\u5e7f\u897f",
#                 "\u7518\u8083",
#                 "\u6c5f\u897f",
#                 "\u5185\u8499\u53e4",
#                 "\u65b0\u7586",
#                 "\u6d77\u5357",
#                 "\u8d35\u5dde",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 2000000,
#         "text": [
#             "High",
#             "Low"
#         ],
#         "textStyle": {
#             "color": "#ddd"
#         },
#         "inRange": {
#             "color": [
#                 "lightskyblue",
#                 "yellow",
#                 "orangered"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "left": "10",
#         "top": "top",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_4e889744aeb141ecbef8bb0f653a1549.setOption(option_4e889744aeb141ecbef8bb0f653a1549);
#         });
#     </script>

# %% [markdown]
# ### (3) 住房问题

# %%
full_view_path = root_path + 't0114.xls'
data = pd.read_excel(io=full_view_path,header=6).dropna()
data.columns = [i for i in range(5)]
data
# Out:
#            0           1           2     3      4
# 1        北京市   4096844.0  11922945.0  2.75  21.03
# 2        天津市   2976741.0   9218220.0  2.23  19.09
# 3        河北省  17934977.0  64296922.0  3.29  22.29
# 4        山西省   8650261.0  31448836.0  3.26  19.28
# 5     内蒙古自治区   6784470.0  22618741.0  1.90  16.38
# 7        辽宁省  12866262.0  40597750.0  2.08  19.67
# 8        吉林省   7848446.0  26076948.0  2.03  17.88
# 9       黑龙江省  10955750.0  35457466.0  1.84  17.53
# 11       上海市   5299068.0  14787225.0  2.10  24.00
# 12       江苏省  21375726.0  69372929.0  2.49  29.17
# 13       浙江省  14136916.0  42437464.0  2.83  35.04
# 14       安徽省  16313885.0  57683856.0  2.53  20.45
# 15       福建省   8743252.0  31251540.0  3.08  24.97
# 16       江西省  10168639.0  38635039.0  2.86  22.81
# 17       山东省  26709328.0  85995937.0  3.56  22.10
# 19       河南省  24247377.0  89285110.0  2.71  21.88
# 20       湖北省  15613793.0  55178797.0  2.65  25.73
# 21       湖南省  17662105.0  61061446.0  2.87  26.93
# 22       广东省  18762127.0  69739958.0  2.65  20.36
# 23   广西壮族自治区  11309236.0  42480672.0  2.71  20.18
# 24       海南省   1750710.0   7191829.0  2.08  15.86
# 26       重庆市   9141558.0  29483651.0  2.48  26.67
# 27       四川省  23638429.0  78760676.0  2.68  28.25
# 28       贵州省   9239409.0  34591772.0  2.21  17.91
# 29       云南省  10853172.0  40474089.0  2.42  20.68
# 30     西藏自治区    531571.0   2526981.0  2.81  13.56
# 32       陕西省   9429484.0  33687093.0  3.02  20.95
# 33       甘肃省   6086988.0  24261648.0  3.89  16.01
# 34       青海省   1173977.0   4643526.0  3.03  17.51
# 35   宁夏回族自治区   1396870.0   5338041.0  2.77  17.43
# 36  新疆维吾尔自治区   4793826.0  17764112.0  2.37  18.06

# %%
area_list_full = data[0].values.tolist()
area_list = [area[:-1] if area not in change_dict.keys() else change_dict[area] for area in area_list_full]
average_house = data[3].values.tolist()
average_area = data[4].values.tolist()

# %%
c = (
    Map()
    .add(
        "average_house",
        [list(z) for z in zip(area_list, average_house)],
        "china"
    )
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_ = 4,is_piecewise=True),
        title_opts=opts.TitleOpts(title="Average_household_Map_For_2000"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="b932563aa095492393ad55e915576c98" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_b932563aa095492393ad55e915576c98 = echarts.init(
#                     document.getElementById('b932563aa095492393ad55e915576c98'), 'white', {renderer: 'canvas'});
#                 var option_b932563aa095492393ad55e915576c98 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "average_house",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 2.75
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 2.23
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 3.29
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 3.26
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 1.9
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 2.08
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 2.03
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 1.84
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 2.1
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 2.49
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 2.83
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 2.53
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 3.08
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 2.86
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 3.56
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 2.71
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 2.65
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 2.87
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 2.65
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 2.71
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 2.08
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 2.48
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 2.68
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 2.21
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 2.42
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 2.81
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 3.02
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 3.89
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 3.03
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 2.77
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 2.37
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "average_house"
#             ],
#             "selected": {
#                 "average_house": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Average_household_Map_For_2000",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 4,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_b932563aa095492393ad55e915576c98.setOption(option_b932563aa095492393ad55e915576c98);
#         });
#     </script>

# %%
c = (
    Map()
    .add(
        "average_housing_area",
        [list(z) for z in zip(area_list, average_area)],
        "china"
    )
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_ = 40,is_piecewise=True),
        title_opts=opts.TitleOpts(title="Average_housing_area_Map_For_2000"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="c9ded8e389ad49769ea48ad77c8315d4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_c9ded8e389ad49769ea48ad77c8315d4 = echarts.init(
#                     document.getElementById('c9ded8e389ad49769ea48ad77c8315d4'), 'white', {renderer: 'canvas'});
#                 var option_c9ded8e389ad49769ea48ad77c8315d4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "average_housing_area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 21.03
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 19.09
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 22.29
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 19.28
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 16.38
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 19.67
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 17.88
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 17.53
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 24.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 29.17
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 35.04
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 20.45
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 24.97
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 22.81
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 22.1
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 21.88
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 25.73
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 26.93
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 20.36
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 20.18
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 15.86
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 26.67
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 28.25
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 17.91
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 20.68
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 13.56
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 20.95
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 16.01
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 17.51
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 17.43
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 18.06
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "average_housing_area"
#             ],
#             "selected": {
#                 "average_housing_area": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Average_housing_area_Map_For_2000",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 40,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_c9ded8e389ad49769ea48ad77c8315d4.setOption(option_c9ded8e389ad49769ea48ad77c8315d4);
#         });
#     </script>
